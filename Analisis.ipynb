# %%
import pandas as pd
ruta3 = "Fase 1 - Scraping-Onion-Sites/output/forum_records.csv"
ruta2 = "Fase 1 - Scraping-Onion-Sites/output/forum_record_limpio.csv"
ruta = "Datos/texto_enriquesido.csv"
datos =pd.read_csv(ruta2)
datos.head(5)
# Out:
#              message_id                       content_fingerprint  \
# 0  msg_2ed41ac5636d9938  1f04bb5ca833aa41b0931383695459ea325395b8
# 1  msg_00898bae4ca9b4c8  df7334506eb8df46196ac3c41773bd31dd437c41
# 2  msg_23e349e53a15e11e  43779a145d6d263695f60a6b636d1770d62d57ec
# 3  msg_2f4b78c0bf2d7c7f  906cfa061a67fea08cba1f64370b93b4539ed6b7
# 4  msg_2cf9b5191d1540ff  c45e06efc6837a73c577b3478a7198d0b05ff35b
#
#                  thread_id      username                         timestamp  \
# 0  thread_0112f3a97cb6cd6b  unknown_user  2026-05-22T02:08:27.214395+00:00
# 1  thread_198b066cd6e07dc8  unknown_user  2026-05-22T02:08:34.825665+00:00
# 2  thread_470b1e44c189f25f      Raja786x  2026-05-22T02:09:10.379667+00:00
# 3  thread_470b1e44c189f25f      baldy200  2026-05-22T02:09:10.383684+00:00
# 4  thread_470b1e44c189f25f      ABTrevor  2026-05-22T02:09:10.387789+00:00
#
#                               fecha   año  mes  dia  hora  \
# ...

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 654 entries, 0 to 653
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   message_id           654 non-null    object
#  1   content_fingerprint  654 non-null    object
#  2   thread_id            654 non-null    object
#  3   username             654 non-null    object
#  4   timestamp            654 non-null    object
#  5   fecha                654 non-null    object
#  6   año                  654 non-null    int64
#  7   mes                  654 non-null    int64
#  8   dia                  654 non-null    int64
#  9   hora                 654 non-null    int64
#  10  title_limpio         652 non-null    object
#  11  body_limpio          654 non-null    object
#  12  quoted_text_limpio   108 non-null    object
#  13  longitud_titulo      654 non-null    int64
#  14  longitud_body        654 non-null    int64
# ...

# %%
datos["user_role"].value_counts()
# Out:
# user_role
# unknown_role    805
# New               1
# 133.32 MB         1
# 101.1 MB          1
# 57.11 GB          1
# 88.43 MB          1
# 16.22 MB          1
# 198.37 MB         1
# 6.01 GB           1
# 35.87 MB          1
# Name: count, dtype: int64
